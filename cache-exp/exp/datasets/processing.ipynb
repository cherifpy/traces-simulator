# %%
import pandas as pd

ds_job = pd.read_csv("/Users/cherif/Documents/Traveaux/datasets/2012-10/job.csv")
ds_job.head()
# Out:
#            jtid  jobid     submitTime     launchTime     finishTime  status  \
# 0  201207231435   4734  1349102009971  1349102024398  1349102177643       0
# 1  201207231435   4735  1349103033999  1349103045081  1349103141374       0
# 2  201207231435   4737  1349107470054  1349107481116  1349107514329       1
# 3  201207231435   4738  1349107665472  1349107676671  1349109302263       0
# 4  201207231435   4739  1349109335001  1349109346757  1349110171820       1
#
#    numMaps  numReduces  finMaps  finReduces  failMaps  failReduces
# 0       60         100       60         100        40           11
# 1       60          30       60          30         2            0
# 2       90          10        2           0         0            0
# 3      648          50      648          50       136            0
# 4      648          50      102           0         0            0

# %%
ds_task = pd.read_csv("/Users/cherif/Documents/Traveaux/datasets/2012-10/task.csv")
ds_task.head()
# Out:
#            jtid  jobid tasktype  taskid      startTime     finishTime  status
# 0  201207231435   4734        m       0  1349102054493  1349102156626     0.0
# 1  201207231435   4734        m       1  1349102054495  1349102159622     0.0
# 2  201207231435   4734        m       2  1349102054503  1349102114569     0.0
# 3  201207231435   4734        m       3  1349102054506  1349102096544     0.0
# 4  201207231435   4734        m       4  1349102054512  1349102102348     0.0

# %%
ds_task = pd.read_csv("/Users/cherif/Documents/Traveaux/datasets/2012-10/split.csv")
ds_task.head()
# Out:
#            jtid  jobid tasktype  taskid  splitid  rack  hostname
# 0  201207231435   4734        m       0        0   NaN       103
# 1  201207231435   4734        m       0        1   NaN       113
# 2  201207231435   4734        m       0        2   NaN       134
# 3  201207231435   4734        m       1        0   NaN        84
# 4  201207231435   4734        m       1        1   NaN       108

# %%
ds_task = pd.read_csv("/Users/cherif/Documents/Traveaux/datasets/2012-10/conf.csv")
ds_task.head()
# Out:
#            jtid  jobid  keyname   value
# 0  201207231435   4734        2    0.80
# 1  201207231435   4734      286    2048
# 2  201207231435   4734        3       5
# 3  201207231435   4734        4  131072
# 4  201207231435   4734        5      10

# %%
ds_task = pd.read_csv("/Users/cherif/Documents/Traveaux/datasets/2012-10/attempt.csv")
ds_task.head()
# Out:
#            jtid  jobid tasktype  taskid  attempt      startTime  shuffleTime  \
# 0  201207231435   4734        m       0        0  1349102054793          NaN
# 1  201207231435   4734        m       0        1  1349102084512          NaN
# 2  201207231435   4734        m       1        0  1349102048866          NaN
# 3  201207231435   4734        m       1        1  1349102084686          NaN
# 4  201207231435   4734        m       2        0  1349102054611          NaN
#
#    sortTime     finishTime  status  rack  hostname
# 0       NaN  1349102163347       2   NaN        52
# 1       NaN  1349102154814       0   NaN        51
# 2       NaN  1349102161913       2   NaN        29
# 3       NaN  1349102158201       0   NaN        67
# 4       NaN  1349102121129       2   NaN        51

# %%
ds_task = pd.read_csv("/Users/cherif/Documents/Traveaux/datasets/2012-10/counter.csv")
ds_task.head()
# Out:
#            jtid  jobid tasktype  taskid  attempt  countergroup  counter  \
# 0  201207231435   4734        ?      -1       -1            71       72
# 1  201207231435   4734        ?      -1       -1            71       73
# 2  201207231435   4734        ?      -1       -1            71       74
# 3  201207231435   4734        ?      -1       -1            71       81
# 4  201207231435   4734        ?      -1       -1             3       75
#
#         value
# 0         123
# 1          43
# 2         100
# 3          57
# 4  2735889406

# %%
import pandas as pd
import numpy as np

# Example DataFrame
data = {
    'Name': ['Tom', 'Jerry', 'Mickey', 'Tom', 'Jerry'],
    'Category': ['Cat', 'Mouse', 'Mouse', 'Cat', 'Mouse']
}
df = pd.DataFrame(data)

df
# Out:
#      Name Category
# 0     Tom      Cat
# 1   Jerry    Mouse
# 2  Mickey    Mouse
# 3     Tom      Cat
# 4   Jerry    Mouse

# %%
# List of elements
elements = [f'ds{i}' for i in range(1, 1001)]

elements
# Out:
# ['ds1',
#  'ds2',
#  'ds3',
#  'ds4',
#  'ds5',
#  'ds6',
#  'ds7',
#  'ds8',
#  'ds9',
#  'ds10',
#  'ds11',
#  'ds12',
#  'ds13',
#  'ds14',
#  'ds15',
#  'ds16',
#  'ds17',
#  'ds18',
#  'ds19',
#  'ds20',
#  'ds21',
#  'ds22',
#  'ds23',
#  'ds24',
#  'ds25',
#  'ds26',
#  'ds27',
#  'ds28',
#  'ds29',
#  'ds30',
#  'ds31',
#  'ds32',
#  'ds33',
#  'ds34',
#  'ds35',
#  'ds36',
#  'ds37',
#  'ds38',
#  'ds39',
#  'ds40',
#  'ds41',
#  'ds42',
#  'ds43',
#  'ds44',
#  'ds45',
#  'ds46',
#  'ds47',
#  'ds48',
#  'ds49',
#  'ds50',
#  'ds51',
#  'ds52',
#  'ds53',
#  'ds54',
#  'ds55',
#  'ds56',
#  'ds57',
#  'ds58',
#  'ds59',
#  'ds60',
#  'ds61',
#  'ds62',
#  'ds63',
#  'ds64',
#  'ds65',
#  'ds66',
#  'ds67',
#  'ds68',
#  'ds69',
#  'ds70',
#  'ds71',
#  'ds72',
#  'ds73',
#  'ds74',
#  'ds75',
#  'ds76',
#  'ds77',
#  'ds78',
#  'ds79',
#  'ds80',
#  'ds81',
#  'ds82',
#  'ds83',
#  'ds84',
#  'ds85',
#  'ds86',
#  'ds87',
#  'ds88',
#  'ds89',
#  'ds90',
#  'ds91',
# ...

# %%
# Define the parameter for the Zipf distribution
a = 2  # This is the parameter for the Zipf distribution. Adjust as necessary.

# Generate Zipf-distributed indices
zipf_indices = np.random.zipf(a, 821132)

zipf_indices
# Out:
# array([ 5,  1, 10, ...,  1,  5,  7])
